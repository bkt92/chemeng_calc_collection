# %%
# %matplotlib inline
#Số Liệu Cân Bằng Pha:
x=(0,2.00E-02,4.00E-02,6.00E-02,8.00E-02,0.1,0.12,0.14,0.16,0.18,0.2,0.22,0.24,0.26,0.28,0.3,0.32,0.34,0.36,0.38,0.4,0.42,0.44,0.46,0.48,0.5,0.52,0.54,0.56,0.58,0.6,0.62,0.64,0.66,0.68,0.7,0.72,0.74,0.76,0.78,0.8,0.82,0.84,0.86,0.88,0.9,0.92,0.94,0.96,0.98,1)
y=(0,4.65E-02,9.08E-02,0.133207746,0.17367947,0.212369924,0.24935753,0.284735523,0.318587954,0.350993173,0.382025018,0.411754106,0.440245841,0.4675626,0.493763023,0.518901999,0.543032412,0.566203094,0.58846163,0.609850261,0.630411474,0.6501848,0.669206518,0.687512104,0.705135047,0.722106223,0.738455555,0.754211168,0.769399724,0.784046479,0.798175372,0.811809122,0.82496927,0.83767648,0.849949742,0.861807732,0.873267994,0.88434719,0.895061211,0.905424217,0.91545348,0.925159748,0.934556733,0.943656984,0.952472849,0.961015626,0.969296172,0.977324906,0.985111724,0.992666163,1)

# %%
figsize(6,6)
plot(x,y,arange(0,1.1,0.1),arange(0,1.1,0.1))
grid()

# %%
xp=0.975
xw=0.001
xf=0.4
i=0
xwt=xw
dxwt={}
while xwt<(xp):
    dxwt[i]=xwt
    xwt=interp(xwt,x,y)
    i=i+1
print(i)
dxwt[i]=interp(dxwt[i-1],x,y)
dxwt
# Out:
# 12
# {0: 0.001,
#  1: 0.002325,
#  2: 0.005405624999999999,
#  3: 0.012568078124999996,
#  4: 0.02922078164062499,
#  5: 0.06692403133398435,
#  6: 0.14721912025581832,
#  7: 0.2969547615170396,
#  8: 0.5150742901431291,
#  9: 0.7344289517107173,
#  10: 0.8812610532038786,
#  11: 0.9530114938152935,
#  12: 0.9823908127123908}
