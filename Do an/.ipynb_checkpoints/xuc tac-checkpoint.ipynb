# %% [markdown]
# k_1=6.147exp((-5673.35)/T)
# k_2=0.683exp((-5268.02)/T)

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
T=np.linspace(70+273.15,150+273.15,100)

# %%
k1=6.147*np.exp(-5673.35/T)
k2=0.683*np.exp(-5268.02/T)

# %%
fig, ax = plt.subplots()
ax.plot(T-273.15,k1,'r*-',label="k1")
ax.plot(T-273.15,k2,label="k2")
plt.xlabel('T(oC)')
ax.legend(loc=2);

# %%
keq=k1/k2

# %%
plt.plot(T-273.15,keq)
plt.xlabel('T (oC)')
plt.ylabel('Keq')

# %% [markdown]
# k_1=4.24*〖10〗^3 exp⁡((-48300)/RT)
# k_2=4.55*〖10〗^5 exp⁡((-66200)/RT)

# %%
R=8.314
k1p=4.24e3*np.exp(-48300/(R*T))
k2p=4.55e5*np.exp(-66200/(R*T))

# %%
fig, ax = plt.subplots()
ax.plot(T-273.15,k1p,'r*-',label="k1")
ax.plot(T-273.15,k2p,label="k2")
plt.xlabel('T(oC)')
ax.legend(loc=2);

# %%
keqp=k1p/k2p
plt.plot(T-273.15,keqp)
plt.xlabel('T (oC)')
plt.ylabel('Keq')

# %%
np.interp(363,T,k1)
# Out:
# 1.0025441982250786e-06

# %%
k_eq
# Out:
# array([ 14.41993425,  13.95531077,  13.509586  ,  13.08185074,
#         12.67124579,  12.27695886,  11.89822171,  11.53430749,
#         11.18452823,  10.84823253,  10.52480334,  10.21365601,
#          9.9142363 ,   9.62601866,   9.34850455,   9.08122089,
#          8.82371859,   8.57557121,   8.33637364,   8.10574093,
#          7.88330717,   7.66872441,   7.46166169,   7.2618041 ,
#          7.0688519 ,   6.8825197 ,   6.7025357 ,   6.52864096,
#          6.36058869,   6.19814365,   6.04108152,   5.88918831,
#          5.74225987,   5.60010133,   5.46252667,   5.32935825,
#          5.20042637,   5.07556888,   4.95463082,   4.83746402,
#          4.72392683,   4.61388371,   4.507205  ,   4.40376661,
#          4.30344975,   4.20614067,   4.11173043,   4.02011465,
#          3.93119333,   3.8448706 ,   3.76105455,   3.67965705,
#          3.60059356,   3.52378299,   3.44914748,   3.37661235,
#          3.30610586,   3.23755912,   3.170906  ,   3.10608291,
# ...

# %%
k11=1.24e9*np.exp(-6105.6/T)
k22=1.34e8*np.exp(-5692.1/T)

# %%
plt.plot(T-273.15,k11,'r*-',T-273.15,k22)
plt.xlabel('T (oC)')

# %%
keq1=k11/k22
plt.plot(T-273.15,keq1)
plt.xlabel('T (oC)')
